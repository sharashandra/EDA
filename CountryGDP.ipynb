# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\shara\OneDrive\Desktop\ClassNotes FSDS\DataFrame_ Pandas\data.csv')
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 0            High income    808.2516
# 1             Low income    207.9927
# 2    Upper middle income    878.3135
# 3    Upper middle income    736.5644
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
#  5   Unnamed: 5     195 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 9.3+ KB

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers   Unnamed: 5
# count  195.000000     195.000000   195.000000
# mean    21.469928      42.076471   653.559009
# std     10.605467      29.030788   351.553521
# min      7.900000       0.900000    28.990400
# 25%     12.120500      14.520000   361.263300
# 50%     19.680000      41.000000   682.074300
# 75%     29.759500      66.225000   892.690170
# max     49.661000      96.546800  1552.589500

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  Unnamed: 5
# 0          High income    808.2516
# 1           Low income    207.9927
# 2  Upper middle income    878.3135
# 3  Upper middle income    736.5644
# 4          High income    971.8720

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Unnamed: 5
# 190  Lower middle income    658.9400
# 191  Upper middle income    969.5250
# 192           Low income     93.2668
# 193  Lower middle income    623.2534
# 194           Low income    660.7275

# %%
df.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
#      Unnamed: 5
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# ...

# %%
df.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup  \
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
#      Unnamed: 5
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# ...

# %%
df.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# Unnamed: 5       0
# dtype: int64

# %%
len(df)
# Out:
# 195

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'Unnamed: 5'],
#       dtype='object')

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers   Unnamed: 5
# count  195.000000     195.000000   195.000000
# mean    21.469928      42.076471   653.559009
# std     10.605467      29.030788   351.553521
# min      7.900000       0.900000    28.990400
# 25%     12.120500      14.520000   361.263300
# 50%     19.680000      41.000000   682.074300
# 75%     29.759500      66.225000   892.690170
# max     49.661000      96.546800  1552.589500

# %%
df.describe().transpose()
# Out:
#                count        mean         std      min       25%       50%  \
# BirthRate      195.0   21.469928   10.605467   7.9000   12.1205   19.6800
# InternetUsers  195.0   42.076471   29.030788   0.9000   14.5200   41.0000
# Unnamed: 5     195.0  653.559009  351.553521  28.9904  361.2633  682.0743
#
#                      75%        max
# BirthRate       29.75950    49.6610
# InternetUsers   66.22500    96.5468
# Unnamed: 5     892.69017  1552.5895

# %%
df.columns = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.columns = ['1', '2', '3', '4', '5', '6']

# %%
df.columns
# Out:
# Index(['1', '2', '3', '4', '5', '6'], dtype='object')

# %%
df.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup', 'Unnamed: 5']

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'Unnamed: 5'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 5', axis = 1)
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
df['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
df[['CountryName', 'BirthRate']]
# Out:
#               CountryName  BirthRate
# 0                   Aruba     10.244
# 1             Afghanistan     35.253
# 2                  Angola     45.985
# 3                 Albania     12.877
# 4    United Arab Emirates     11.044
# ..                    ...        ...
# 190           Yemen, Rep.     32.947
# 191          South Africa     20.850
# 192      Congo, Dem. Rep.     42.394
# 193                Zambia     40.471
# 194              Zimbabwe     35.715
#
# [195 rows x 2 columns]

# %%
df[['CountryName', 'BirthRate']].head()
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
df[1:6][['CountryName', 'BirthRate']]
# Out:
#             CountryName  BirthRate
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df_categorical = df[['CountryName', 'CountryCode', 'IncomeGroup']]
df_categorical.head()
# Out:
#             CountryName CountryCode          IncomeGroup
# 0                 Aruba         ABW          High income
# 1           Afghanistan         AFG           Low income
# 2                Angola         AGO  Upper middle income
# 3               Albania         ALB  Upper middle income
# 4  United Arab Emirates         ARE          High income

# %%
df_categorical.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df_categorical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryName  195 non-null    object
#  1   CountryCode  195 non-null    object
#  2   IncomeGroup  195 non-null    object
# dtypes: object(3)
# memory usage: 4.7+ KB

# %%
df['CountryName'] = df['CountryName'].astype('category')
df['CountryCode'] = df['CountryCode'].astype('category')
df['IncomeGroup'] = df['IncomeGroup'].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    category
#  1   CountryCode    195 non-null    category
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    category
# dtypes: category(3), float64(2)
# memory usage: 15.5 KB

# %%
df.BirthRate * df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df['var'] = df.BirthRate * df.InternetUsers
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup       var
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
df = df.drop('var', axis = 1)
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
filter = df.BirthRate < 20.0
filter
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
filter.sum()
# Out:
# 100

# %%
filter.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# Name: BirthRate, dtype: bool

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df[20:31]
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 20                   Belarus         BLR     12.500          54.17
# 21                    Belize         BLZ     23.092          33.60
# 22                   Bermuda         BMU     10.400          95.30
# 23                   Bolivia         BOL     24.236          36.94
# 24                    Brazil         BRA     14.931          51.04
# 25                  Barbados         BRB     12.188          73.00
# 26         Brunei Darussalam         BRN     16.405          64.50
# 27                    Bhutan         BTN     18.134          29.90
# 28                  Botswana         BWA     25.267          15.00
# 29  Central African Republic         CAF     34.076           3.50
# 30                    Canada         CAN     10.900          85.80
#
#             IncomeGroup
# 20  Upper middle income
# 21  Upper middle income
# 22          High income
# 23  Lower middle income
# 24  Upper middle income
# ...

# %%
df[filter]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244           78.9
# 3                           Albania         ALB     12.877           57.2
# 4              United Arab Emirates         ARE     11.044           88.0
# 5                         Argentina         ARG     17.716           59.9
# 6                           Armenia         ARM     13.308           41.9
# ..                              ...         ...        ...            ...
# 181                   United States         USA     12.500           84.2
# 183  St. Vincent and the Grenadines         VCT     16.306           52.0
# 184                   Venezuela, RB         VEN     19.842           54.9
# 185           Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                         Vietnam         VNM     15.537           43.9
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vis1 = sns.distplot(df['InternetUsers'])

# %%
vis1 = sns.displot(df['InternetUsers'])
plt.show()

# %%
vis2 = sns.scatterplot(data = df, x = 'BirthRate', y = 'InternetUsers', hue = 'IncomeGroup')
plt.show()

# %%
vis = sns.lineplot(data = df, x = 'BirthRate', y = 'InternetUsers')
plt.show()

# %%
vis3 = sns.lmplot(data = df, x = 'BirthRate', y = 'InternetUsers', hue = 'IncomeGroup')
plt.show()

# %%
vis3 = sns.lmplot(data = df, x = 'BirthRate', y = 'InternetUsers', hue = 'IncomeGroup', fit_reg = False)
plt.show()

# %%
sns.lmplot(data = df, x = 'InternetUsers', y = 'BirthRate', hue = 'IncomeGroup', fit_reg = False, height = 7)

# %%
sns.barplot(data = df, x = 'BirthRate', y = 'InternetUsers', hue = 'IncomeGroup')
# Out:
# <Axes: xlabel='BirthRate', ylabel='InternetUsers'>

# %%
sns.boxplot(df['BirthRate'])
# Out:
# <Axes: ylabel='BirthRate'>

# %%
sns.boxplot(df['InternetUsers'])
# Out:
# <Axes: ylabel='InternetUsers'>

# %%
sns.boxplot(
